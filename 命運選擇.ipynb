# %% [markdown]
# <a href="https://colab.research.google.com/github/SHU115/Computational-Thanking-and-Program-Design/blob/main/%E5%91%BD%E9%81%8B%E9%81%B8%E6%93%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *試打版本*
#
# ---
# **`試玩、編輯，請移至下方進行更改`**

# %%
##命運知人遊戲

print("嗨！尊貴的客人你好，歡迎來到命運之人遊戲！")
print("我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。")
print("在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。")
print("從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!")
print("由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供三個不同的角色。")
print("現在您可以任選其中一個去體驗並做出影響角色命運的決定。")
name=input("現在，請問要怎麼稱呼您呢?")
print(f"您好{name}，簡單的跟你介紹一下遊戲規則。?")

##遊戲開始
print("在你前方有三個選擇，分別是有著軍事背景的小男孩、從小缺乏父愛的小女孩還有碰上離奇洞口的年輕人。")
id_choice=input("軍事背景的小男孩、缺乏父愛的小女孩還有碰上離奇洞口的年輕人")
if id_choice == "小男孩/男孩/軍事背景": # ID選擇
 print("確認過的話，我要請你閉上眼")
 print("恭喜您，來到這個世界") 
 print("現在為您介紹男孩誕生的家庭")
 print("爸爸是一位大企業的老闆，媽媽則是一間跨國企業的執行長，兩人都對孩子疼愛有加，從小讓他接受很好的教育，只是父母都不太有時間陪伴他...") 

 action1=input("事件發生!!南美洲與美國邊界因為飢荒突然發生大規模難民戰爭，爸爸在南美經商的時候被當地反抗軍抓住，媽媽動用了軍方人脈部屬了一批綠扁帽特種部隊前往營救，該讓任務成功還是失敗？")
 if action1 == "成功":
  print("爸爸順利被特種部隊營救出來，但是因為被激進份子凌辱過非常生氣決定報復，決定偷偷資助當地政府軍大量軍火和生化武器，內戰加劇，平民和反抗軍死傷慘重，小男孩對新聞上的那些難民遭遇感到麻木，他認為那些事離他還很遙遠，父母對他的溺愛很快使他變成遊手好閒之人")
 elif action1 == "失敗":
  print("特種部隊抵達前爸爸已被反抗軍殺死，小男孩非常悲憤，繼承爸爸的龐大遺產後，繼續經營父親的事業，發憤圖強")

 action2=input("有一個很可愛的女孩子出現在小男孩周遭，該不該讓他們相遇? 請回答是與否!")
 if action2 == "是":
  print("男孩很欣賞女孩的聰慧和純潔，決定也要向他學習，開始認真讀書，很快他們相戀並過起甜蜜的生活...")
 elif action2 == "否":
  print("男孩與女孩錯過，男孩繼續遊手好閒，父母看不下去將他送到軍校，男孩在軍中接受嚴厲的磨練，下部隊後該將它分配到哪一個作戰單位?")

 action3=input("空軍、陸軍或是海軍")
 if action3 == "空軍":
  print("男孩成為一位空軍軍官，後來靠著家庭背景當上了將軍，不久後再度發生戰爭，面對戰況失利的他忍無可忍，下令無差別轟炸所有可能的反抗軍據點，死傷數百萬人，陸地化作一片民不聊生的焦土地獄，難民湧入各國邊境，同時也帶來了可怕的傳染病，人類遭遇了前所未有的大滅絕 ~The End")
 elif action3 == "陸軍":
  print("男孩成為一位陸軍軍官，後來靠著家庭背景當上了將軍，不久再度發生戰爭，面對戰況失利的他忍無可忍，下令無差別屠殺敵國所有活著的人，死傷數百萬人，剩下的難民變恐怖分子逃到別國發動了恐怖攻擊，釋放了危險的生化武器毀滅所有人類，地球不再適宜居住，人類滅絕 ~ The End")
 elif action3 == "海軍":
  print("男孩成為一位海軍軍官，後來靠著家庭背景當上了將軍，不久再度發生戰爭，面對戰況失利的他忍無可忍，下令軍艦無差別砲轟所有沿岸船隻和港口，封鎖海岸線，不料士兵失誤擊沉別國船艦，世界大戰爆發，死傷無數，人類滅絕 ~ The End")
# Out:
# 嗨！尊貴的客人你好，歡迎來到命運之人遊戲！
# 我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。
# 在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。
# 從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!
# 由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供三個不同的角色。
# 現在您可以任選其中一個去體驗並做出影響角色命運的決定。
# 現在，請問要怎麼稱呼您呢?533
# 您好533，簡單的跟你介紹一下遊戲規則。?
# 在你前方有三個選擇，分別是有著軍事背景的小男孩、從小缺乏父愛的小女孩還有碰上離奇洞口的年輕人。
# 軍事背景的小男孩、缺乏父愛的小女孩還有碰上離奇洞口的年輕人小女孩

# %% [markdown]
# # `**命運之人2**`
# ### **第一版**
#
#
# ---
# #目前失敗:
# 問題在於，無法中斷問答方法。對於題中題無法完成!

# %%
##命運知人遊戲
print("嗨！尊貴的客人你好，歡迎來到命運之人遊戲！")
print("我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。")
print("在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。")
print("從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!")
print("由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供三個不同的角色。")
print("現在您可以任選其中一個去體驗並做出影響角色命運的決定。")
name=input("現在，請問要怎麼稱呼您呢?")
print(f"您好{name}，簡單的跟你介紹一下遊戲規則。?")

##遊戲開始
print("在你前方有三個選擇，分別是有著軍事背景的小男孩、從小缺乏父愛的小女孩還有碰上離奇洞口的年輕人。")
do=input("::")
if do == "男孩":
 print("確認過的話，我要請你閉上眼")
 print("-----即將進入遊戲世界-----")
 print("恭喜您，來到這個世界")
 print("現在為您介紹男孩誕生的家庭")
 print("爸爸是一位大企業的老闆，媽媽則是一間跨國企業的執行長，兩人都對孩子疼愛有加，從小讓他接受很好的教育，只是父母都不太有時間陪伴他...")
action=input("事件發生!!南美洲與美國邊界因為飢荒突然發生大規模難民戰爭，爸爸在南美經商的時候被當地反抗軍抓住，媽媽動用了軍方人脈部屬了一批綠扁帽特種部隊前往營救，該讓任務成功還是失敗?")
if do == "成功":
  print("爸爸順利被特種部隊營救出來，但是因為被激進份子凌辱過非常生氣決定報復，決定偷偷資助當地政府軍大量軍火和生化武器，內戰加劇，平民和反抗軍死傷慘重，小男孩對新聞上的那些難民遭遇感到麻木，他認為那些事離他還很遙遠，父母對他的溺愛很快使他變成遊手好閒之人")
elif do == "失敗":
  print("特種部隊抵達前爸爸已被反抗軍殺死，小男孩非常悲憤，繼承爸爸的龐大遺產後，繼續經營父親的事業，發憤圖強")

action2=input("有一個很可愛的女孩子出現在小男孩周遭，該不該讓他們相遇? 請回答是與否!")
if action2 == "是":
  print("男孩很欣賞女孩的聰慧和純潔，決定也要向他學習，開始認真讀書，很快他們相戀並過起甜蜜的生活...")
elif action2 == "否":
  print("男孩與女孩錯過，男孩繼續遊手好閒，父母看不下去將他送到軍校，男孩在軍中接受嚴厲的磨練，下部隊後該將它分配到哪一個作戰單位?")

action3=input("空軍、陸軍或是海軍")
if action3 == "空軍":
  print("男孩成為一位空軍軍官，後來靠著家庭背景當上了將軍，不久後再度發生戰爭，面對戰況失利的他忍無可忍，下令無差別轟炸所有可能的反抗軍據點，死傷數百萬人，陸地化作一片民不聊生的焦土地獄，難民湧入各國邊境，同時也帶來了可怕的傳染病，人類遭遇了前所未有的大滅絕 ~The End")
elif action3 == "陸軍":
  print("男孩成為一位陸軍軍官，後來靠著家庭背景當上了將軍，不久再度發生戰爭，面對戰況失利的他忍無可忍，下令無差別屠殺敵國所有活著的人，死傷數百萬人，剩下的難民變恐怖分子逃到別國發動了恐怖攻擊，釋放了危險的生化武器毀滅所有人類，地球不再適宜居住，人類滅絕 ~ The End")
elif action3 == "海軍":
  print("男孩成為一位海軍軍官，後來靠著家庭背景當上了將軍，不久再度發生戰爭，面對戰況失利的他忍無可忍，下令軍艦無差別砲轟所有沿岸船隻和港口，封鎖海岸線，不料士兵失誤擊沉別國船艦，世界大戰爆發，死傷無數，人類滅絕 ~ The End")

if id_choice == "女孩/小女孩/缺乏父愛的小女孩": 
 print("現在為您介紹女孩誕生的家庭")
 print("您的父親是一位大企業的老闆,母親是一間跨國企業的執行長。")
 print("兩人都對孩子疼愛有加,從小讓他接受很好的教育,只是父母都不太有時間陪伴他...")

action4=input("事件：世界發生前所未有的金融海嘯危機，嚴重的程度導致爸媽的工作都受到極大的影響，這時他們兩人選擇跨公司合作，爸爸提供自家公司的資源補足媽媽缺乏的國外金源；媽媽則沒日沒夜地當強而有力的賢內助，但這一忙碌下來使媽媽體力透支，健康狀況每況愈下。該不該讓父母雙方的公司都能渡過危機? 請回答是與否!")
if action4 == "是":
  print("最終父母的公司耗時多日，都成功化解困境，但媽媽不幸因過勞離開人世，她原先經營的公司就由爸爸代為接手並整合內部資源。因為更加忙碌的關係，你的童年幾乎只有爸爸指派的秘書阿玲陪伴著妳")
elif action4 == "否":
  print("爸媽將自己的股份全權釋出，交給其他股東們處理，想當然最後都面臨倒閉的命運，但爸爸其實有不少存款，得以讓媽媽到院治療重獲健康")

action5=input("在學校因為嬌生慣養的性格，成為班上大多數人的眼中釘，選擇是否知情？")
if action5 == "是":
  print("知道自己個性問題後的妳，漸漸改變舊有的大小姐脾氣，變得善解人意、和藹可親，交到了幾個很投合的知心朋友，大家都對妳改觀，包含原先快容忍不了妳的阿玲")
elif action5 == "否":
  print("依舊囂張跋扈，但內心又十分渴望友情的存在，其實只是希望能在父母以外的人身上找到依靠。但不擅表達只會把內心話告訴阿玲，結果不小心把自己的心意也告訴了他，他並沒有接受妳的心意，換來妳無限的悲憤和心痛。")

action6=input("過沒多久後迎接升大學的挑戰，是否選擇參加考試?")
if action6 == "是":
  print("雖然難過了一陣子，但知道考大學還是比較重要的妳，依舊認真準備不久後的學測，上了一間還行的私立大學，但因個性問題造成妳獨來獨往，成為與他人沒什麼連結的系邊，這時妳早已離開爸爸和阿玲的視線，畢業後靠自己白手起家，一開始的確成效頗佳，但最後股東們實在受不了妳的爛脾氣紛紛走人，公司面臨倒閉")
elif action6 == "否":
  print("不選擇參加學測，於是順理成章到爸爸公司學習公司運作的妳，很有天分的對於管理各部門相當得心應手，知道員工和股東想要的利益面是什麼，爸爸退休後就由妳繼承公司，但發現阿玲和旗下員工在一起，妳覺得超嘔又憤恨，於是把他們逐出公司，也因此浮現各種大大小小的毛病，公司最後仍不敵倒閉的命運")

action7=input("爸爸慢慢看見妳的好，試圖和妳修復因長時間沒陪伴妳而疏遠的父女關係，但出自防衛心理，妳感到莫名其妙，並無意和爸爸大吵了一架奪門而出。這時妳在奔跑的過程迎面而來一輛水泥車... 請選擇注意或失意!")
if action7 == "注意":
  print("和死神交叉而過，頓悟生命誠可貴，也體恤到爸爸在自己成長過程中付出的是雙倍的辛勞，於是回家和爸爸道歉後奮發圖強，如願考取理想大學，在校園中很受同學們歡迎，遇到了真心喜歡妳的男孩子，雖然沒有阿玲帥，但妳和他成為廣電系神鵰俠侶，畢業後選擇投身影視產業，由阿玲繼承爸爸的公司，但妳時不時會替公司代言產品，也早已想通那時對阿玲的好感只不過是希望有人能愛自己，如今已和所愛比翼雙飛了~The End")
elif action7 == "失意":
  print("半身不遂的妳，日後的人生都需要靠他人協助，爸爸感到非常不捨和抱歉，只好解雇阿玲、辭去工作，找個勉強能工作的飯碗照顧著妳後續的生活起居~The End")

if id_choice == "離奇洞口/年輕人/碰上離奇洞口的年輕人":
 print("昨晚下了一場異常大的雨，而且還伴隨著可怕的颱風。")
 print("颱風過後的今天，晴空萬里。")
 print("離城市不遠的一個村莊收到了颱風的破壞，不過損失不算嚴重。")
 print("就只有村外山腳下的那座小小古廟被颱風連根吹走了，不過並不是什麼大礙。")
 
action8=input("你今天經過了一群村民旁邊，感覺他們在議論什麼，要過去聽嗎？（是/否）")
if action8 == "是":
  print("你往村民的方向走了過去，想聽聽看他們在說什麼。")
  print(":那座廟是哪一個年代遺留下來的啊？")
  print(":好不吉利，感覺得趕快重建一座新的廟。")
  print("正當村民你一眼我一語的時候，有一個人神色慌張的跑過來。")
  print("“不得了啊，出現怪事了！怎麼了怎麼了！發生了什麼事？")
  
elif action8 == "否":
  print("你經過了那群七嘴八舌討論著什麼的村民，徑直的往被廟的方向走去，雖然那邊已經沒有什麼廟了。")
  print("不過你內心中隱約覺得那邊有著什麼東西，結果你發現原本廟的位置地上出現了一個奇怪的大洞！")
  print("這時你按耐不住內心的驚訝大喊:不得了啊，出現怪事了！")
  print("這時村民們全被你吸引了過來，怎麼了怎麼了！發生了什麼事？")
  print("大家突然聽到你大叫，都圍過來看看發生了什麼事。")
  print("那個洞口就像在吸引著你，你靠了過去然後對著洞口喊了一聲。")
  print("喂！出來！")

action9=print("你見沒有任何回音從洞裡傳上來，旁邊有一塊小石頭，要試試看丟進洞裡嗎？(是/否)")
if action9 == "是":
  print("這時候你看到對面有人向你搖手示意不要那麼做。")
  print("不過已經來不及了，你把石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。")
elif action8 == "否":
  print("你後來想想還是算了，這時候旁邊有一個年輕人卻自顧自的撿起那塊石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。")

print("這時候村民帶來了許多的樹枝和繩子圍繞著洞口做了一個簡易的圍欄，大家就先回去村莊裡了。")
print("大家也不知道該拿這個洞口怎麼辦。")
print("隨著時間一天天過去，知道這洞口的人越來越多。")
print("消息靈通的報社記者們很快就打聽到了這件事，全都匆忙的趕來村莊一探究竟。")
print("不到一時半刻，許多的科學家和學者也都聞風趕來。")
print("陸陸續續的來的人越來越多，有的人露出貪婪的目光反覆的打量這個洞口，在心裡盤算是否有利可圖。")
print("警察們則守衛在洞口周圍，深怕有人不小心靠太近掉下去。")

action10=print("你今天又經過了洞口，有一個記者向你揮手尋求幫忙，同時又有一個學者叫住了你，你會回應誰？（記者/學者）")
if action10 == "記者":
  print("那個新聞記者不知從哪裡弄來了一根很長的繩子，他叫你幫他把繩子綁在重物的另一端，小心翼翼的往下放。")
  print("繩子就這樣一尺一尺的放了下去，可是等到繩子放完卻拉不起來了!記者這時候又叫了更多的人來幫忙，不管怎麼使勁拉，都拉不起來，感覺另一端有什麼在拉扯著。")
  print("這時候繩子突然卡的一聲不知道在洞裡的什麼地方斷掉了，一堆大男人全都重心不穩摔倒在地，村民們還有記者覺得太丟臉了，也覺得這個洞太詭異了，有點邪乎，於是大夥兒決定要把洞填掉。")
elif action10 == "否":
  print("學者不知道從哪弄來了一台大功率擴音器，準備對洞裡回傳的回聲做頻率分析。")
  print("不過他一個人可做不來，還有你有過去幫忙學者。")
  print("你看他把擴音機擺弄了很久，各種聲音都試過了，可是卻連洞裡的半點聲音都沒有聽到，就算把音量開到最大限度也沒用。")
  print("學者苦苦思索著，不管眾目睽睽之下就此作罷絕對會遭人恥笑不夠專業。")
  print("他裝著鎮定、胸有成竹的樣子關掉了擴音器，對大家說到這個洞口絕對是輻射量水平很高才會影響機器，還是填掉為妙。")
  print("村民們便決定要把洞填掉。")

print("周圍那些看熱鬧的人覺得有點可惜，難道就要這樣草草收場了？")
print("正當大家要掃興而歸的時候，有個人滿頭大汗的從人群裡擠了出來。")
print(":請吧這個洞口讓給我吧，賣給我也行，我來負責幫你們填")
print("那個人就是一開始反覆打量這個洞口的商人。")
print("不過村裡的村長卻不同意，他覺得有人幫忙填洞固然是好事，不過還是應該要重建一座廟。")

action11=print("你心裡反覆思考要幫助這個商人嗎？（是/否）")
if action11 == "是":
  print("作為村里很有誠信的年輕人，你覺得有人幫忙填洞無非是壞事，於是便率先出來贊同商人的提議。")
  print("商人也藉機提出交易。")
  print(":我可以幫忙你們建造一座新的廟，更出色而且離你們村子更近的廟，怎麼樣？")
  print("村長還來不及回答，村民們卻也收到你的影響，異口同聲贊同了起來。")
  print("村長見狀也不好說什麼")
  print(":一個洞口也沒什麼特別的，就送給你吧")
  print("於是，這筆交易就在你的協助下成交了。")
elif action11 == "否":
  print("後來商人不過費盡多少口舌，都說服不了村長把洞口賣給他，只好失落的離去。")
  print("村長覺得畢竟是村子裡的事，交給一個外人來負責太奇怪了，更何況那邊本該是一座廟啊。")
  print("作為村子裡最有誠信的年輕人，村長把興建新廟的任務交給了你。")

print("後來興建新廟的工作如火如荼的進行，可是這個洞口卻有一股魔力。")
print("不管是什麼東西要建在洞口上面都會掉下去，而且不管填了幾次都沒有辦法填滿，連廟的地基都沒有辦法打。")
print("後來你找了一個更適合的地方建廟，這個洞口之後也在商人不斷的交涉之下賣給了他。")
print("商人買下洞口後便在附近建造了一個小房子，門上掛著一個小小的招牌「填洞公司」。")
print("在城裡的時候偶爾會聽到有人在宣傳那個洞口，似乎是新的公司口號。")
print(":本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！")
print("不久後，政府有關部門也發出了營業許可證，許多的能源開發店家也紛紛來簽訂合約，一開始村里的大家還很擔心，害怕會發生什麼事。")
print("「填洞公司」也派人對村民進行說明，這是一個非常保險的洞，丟進裡面的東西經過了上千年也不會對地面造成危害，而且來的人越多，村里就越容易繁榮啊。")
print("大家也開始漸漸放下了心來，畢竟自從這門生意開始後，村里的經濟狀況確實越來越好了。")
print("來洞口的人越來越多，每個禮拜都會有卡車源源不斷的把核廢料載過來處理。")
print("外交部和國防部也會把那些見不得光的機密文件連同保險櫃一起丟到洞裡去。")
print("失戀的人們也都把從前代表者愛情的回憶丟進洞裡，再去開始一段新的戀情。")
print("許多的犯罪分子也紛紛把一些屍體、犯罪證據、兇器扔進洞裡再逍遙法外。")
print("不管是把什麼丟進去，這個洞都會慷慨大方的一視同仁，招收不誤，似乎真的永遠也填不滿。")
print("這個洞幫過度開發，烏煙瘴氣的城市洗著各種骯髒的東西，漸漸的海洋和天空又恢復了美麗的蔚藍色。")

action12=print("距離發現這個洞已是三年的時間，想來有點感慨，要去洞口那邊看看嗎？（是/否）")
if action12 == "是":
  print("你仔細了端詳一下洞口，他還是跟當初的一樣，卻又顯得哪裡有點不一樣。")
  print("你由衷的感謝這個任勞任怨的洞口。")
  print("後來你轉身離去，望著天空讚嘆世界變得越來越美好了！")
  print(":喂！出來！，聽到聲音後你戛然而止，思索著剛剛的那個聲音，感覺好像在哪裡聽過。")
  print("望了望附近確定沒人，想著可能是天氣太熱了有點頭暈產生錯覺。")
  print("決定要回家好好休息一番，突然剛剛發出聲音的地方飛來一塊是天氣，從你面前一閃而過掉在了地上。")
  print("當然，那快微不足道的石頭根本沒引起你的注意。")
  print("此刻的你瞇著眼望向天空，望向這個美好的世界。THE END")
elif action12 == "否":
  print("這時候的你已經成家立業，想想等等兒子要回來了，還是算了吧。")
  print("正想到這兒子回來了，他今天看起來特別開心。")
  print("告訴我他今天在學校碰到的趣事，還有他又去洞口完了。")
  print("真不知道他也對那個洞口深深著迷是遺傳到誰。")
  print("他說今天又去那邊探望那個偉大的洞口了，還聽到有人叫了他，不管轉頭卻又沒有看到人。")
  print("不過你不知道的是，兒子聽到的聲音。")
  print("喂！出來")
  print("你也沒有注意到，兒子從那邊帶回了一塊微不足道的小石頭。THE END")
print("--------蹦 時間已到--------")
print("喂喂！｛name｝醒來嘍！")
print("遊玩時間已經到了，不知道你對命運遊戲的劇情還滿意嗎？")
print("希望你剛剛有一個非常愉快的遊玩體驗，結束之後是否對你的人生觀有著什麼改變呢。")
print("你的回饋將會是我們的進步，那下次記得再回來玩喔！感謝你！")
# Out:
# 嗨！尊貴的客人你好，歡迎來到命運之人遊戲！
# 我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。
# 在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。
# 從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!
# 由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供三個不同的角色。
# 現在您可以任選其中一個去體驗並做出影響角色命運的決定。
# 現在，請問要怎麼稱呼您呢?533
# 您好533，簡單的跟你介紹一下遊戲規則。?
# 在你前方有三個選擇，分別是有著軍事背景的小男孩、從小缺乏父愛的小女孩還有碰上離奇洞口的年輕人。
# ::男孩
# 確認過的話，我要請你閉上眼
# -----即將進入遊戲世界-----
# 恭喜您，來到這個世界
# 現在為您介紹男孩誕生的家庭
# 爸爸是一位大企業的老闆，媽媽則是一間跨國企業的執行長，兩人都對孩子疼愛有加，從小讓他接受很好的教育，只是父母都不太有時間陪伴他...
# 事件發生!!南美洲與美國邊界因為飢荒突然發生大規模難民戰爭，爸爸在南美經商的時候被當地反抗軍抓住，媽媽動用了軍方人脈部屬了一批綠扁帽特種部隊前往營救，該讓任務成功還是失敗?成功
# 有一個很可愛的女孩子出現在小男孩周遭，該不該讓他們相遇? 請回答是與否!是
# 男孩很欣賞女孩的聰慧和純潔，決定也要向他學習，開始認真讀書，很快他們相戀並過起甜蜜的生活...
# 空軍、陸軍或是海軍空軍
# 男孩成為一位空軍軍官，後來靠著家庭背景當上了將軍，不久後再度發生戰爭，面對戰況失利的他忍無可忍，下令無差別轟炸所有可能的反抗軍據點，死傷數百萬人，陸地化作一片民不聊生的焦土地獄，難民湧入各國邊境，同時也帶來了可怕的傳染病，人類遭遇了前所未有的大滅絕 ~The End
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
